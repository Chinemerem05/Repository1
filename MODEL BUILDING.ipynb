# %%
import pandas as pd
import warnings
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data= pd.read_csv('Test_sales_LinReg.csv')

# %%
data.head()
# Out:
#    Republic  NDTV   TV5   TV9  AajTak  sales
# 0       8.7  48.9   4.0  75.0    49.0    7.2
# 1      57.5  32.8  65.9  23.5    57.5   11.8
# 2     120.2  19.6   7.2  11.6    18.5   13.2
# 3       8.6   2.1  46.0   1.0     2.6    4.8
# 4     199.8   2.6  52.9  21.2     2.9   10.6

# %%
data.shape
# Out:
# (305, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Republic  295 non-null    float64
#  1   NDTV      300 non-null    float64
#  2   TV5       305 non-null    float64
#  3   TV9       297 non-null    float64
#  4   AajTak    300 non-null    float64
#  5   sales     305 non-null    float64
# dtypes: float64(6)
# memory usage: 14.4 KB

# %%
data.isna().sum()
# Out:
# Republic    10
# NDTV         5
# TV5          0
# TV9          8
# AajTak       5
# sales        0
# dtype: int64

# %%
data.tail()
# Out:
#      Republic  NDTV   TV5   TV9  AajTak  sales
# 300     286.0  13.9  35.2   3.7    13.9   15.9
# 301      18.7  12.1  23.7  23.4    18.7    6.7
# 302      39.5  41.1  17.6   5.8    39.5   10.8
# 303      75.5  10.8   8.3   6.0    75.5    9.9
# 304      17.2   4.1  30.0  31.6    17.2    5.9

# %%
data.head()
# Out:
#    Republic  NDTV   TV5   TV9  AajTak  sales
# 0       8.7  48.9   4.0  75.0    49.0    7.2
# 1      57.5  32.8  65.9  23.5    57.5   11.8
# 2     120.2  19.6   7.2  11.6    18.5   13.2
# 3       8.6   2.1  46.0   1.0     2.6    4.8
# 4     199.8   2.6  52.9  21.2     2.9   10.6

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.read_csv('Test_sales_LinReg.csv')
df
# Out:
#      Republic  NDTV   TV5   TV9  AajTak  sales
# 0         8.7  48.9   4.0  75.0    49.0    7.2
# 1        57.5  32.8  65.9  23.5    57.5   11.8
# 2       120.2  19.6   7.2  11.6    18.5   13.2
# 3         8.6   2.1  46.0   1.0     2.6    4.8
# 4       199.8   2.6  52.9  21.2     2.9   10.6
# ..        ...   ...   ...   ...     ...    ...
# 300     286.0  13.9  35.2   3.7    13.9   15.9
# 301      18.7  12.1  23.7  23.4    18.7    6.7
# 302      39.5  41.1  17.6   5.8    39.5   10.8
# 303      75.5  10.8   8.3   6.0    75.5    9.9
# 304      17.2   4.1  30.0  31.6    17.2    5.9
#
# [305 rows x 6 columns]

# %%
df_no_missing = df.dropna()
df_no_missing
# Out:
#      Republic  NDTV   TV5   TV9  AajTak  sales
# 0         8.7  48.9   4.0  75.0    49.0    7.2
# 1        57.5  32.8  65.9  23.5    57.5   11.8
# 2       120.2  19.6   7.2  11.6    18.5   13.2
# 3         8.6   2.1  46.0   1.0     2.6    4.8
# 4       199.8   2.6  52.9  21.2     2.9   10.6
# ..        ...   ...   ...   ...     ...    ...
# 300     286.0  13.9  35.2   3.7    13.9   15.9
# 301      18.7  12.1  23.7  23.4    18.7    6.7
# 302      39.5  41.1  17.6   5.8    39.5   10.8
# 303      75.5  10.8   8.3   6.0    75.5    9.9
# 304      17.2   4.1  30.0  31.6    17.2    5.9
#
# [282 rows x 6 columns]

# %%
df
# Out:
#      Republic  NDTV   TV5   TV9  AajTak  sales
# 0         8.7  48.9   4.0  75.0    49.0    7.2
# 1        57.5  32.8  65.9  23.5    57.5   11.8
# 2       120.2  19.6   7.2  11.6    18.5   13.2
# 3         8.6   2.1  46.0   1.0     2.6    4.8
# 4       199.8   2.6  52.9  21.2     2.9   10.6
# ..        ...   ...   ...   ...     ...    ...
# 300     286.0  13.9  35.2   3.7    13.9   15.9
# 301      18.7  12.1  23.7  23.4    18.7    6.7
# 302      39.5  41.1  17.6   5.8    39.5   10.8
# 303      75.5  10.8   8.3   6.0    75.5    9.9
# 304      17.2   4.1  30.0  31.6    17.2    5.9
#
# [305 rows x 6 columns]

# %%
df_cleaned = df.dropna(how='all')
df_cleaned
# Out:
#      Republic  NDTV   TV5   TV9  AajTak  sales
# 0         8.7  48.9   4.0  75.0    49.0    7.2
# 1        57.5  32.8  65.9  23.5    57.5   11.8
# 2       120.2  19.6   7.2  11.6    18.5   13.2
# 3         8.6   2.1  46.0   1.0     2.6    4.8
# 4       199.8   2.6  52.9  21.2     2.9   10.6
# ..        ...   ...   ...   ...     ...    ...
# 300     286.0  13.9  35.2   3.7    13.9   15.9
# 301      18.7  12.1  23.7  23.4    18.7    6.7
# 302      39.5  41.1  17.6   5.8    39.5   10.8
# 303      75.5  10.8   8.3   6.0    75.5    9.9
# 304      17.2   4.1  30.0  31.6    17.2    5.9
#
# [305 rows x 6 columns]

# %%
df.dropna(axis=1, how='all')
df
# Out:
#      Republic  NDTV   TV5   TV9  AajTak  sales
# 0         8.7  48.9   4.0  75.0    49.0    7.2
# 1        57.5  32.8  65.9  23.5    57.5   11.8
# 2       120.2  19.6   7.2  11.6    18.5   13.2
# 3         8.6   2.1  46.0   1.0     2.6    4.8
# 4       199.8   2.6  52.9  21.2     2.9   10.6
# ..        ...   ...   ...   ...     ...    ...
# 300     286.0  13.9  35.2   3.7    13.9   15.9
# 301      18.7  12.1  23.7  23.4    18.7    6.7
# 302      39.5  41.1  17.6   5.8    39.5   10.8
# 303      75.5  10.8   8.3   6.0    75.5    9.9
# 304      17.2   4.1  30.0  31.6    17.2    5.9
#
# [305 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Republic    10
# NDTV         5
# TV5          0
# TV9          8
# AajTak       5
# sales        0
# dtype: int64

# %%
df[df['Republic'].isna()]
# Out:
#      Republic  NDTV   TV5   TV9  AajTak  sales
# 139       NaN  39.7  19.3  37.7    39.7   19.0
# 140       NaN  21.1  31.3   9.5    21.1   15.6
# 141       NaN  11.6  13.1   5.7    11.6    3.2
# 142       NaN  43.5  89.4  50.5    43.5   15.3
# 143       NaN   1.3  20.7  24.3     1.3   10.1
# 144       NaN  36.9  14.2  45.2    36.9    7.3
# 145       NaN  18.4   9.4  34.6    18.4   12.9
# 146       NaN  18.1  23.1  30.7    18.1   14.4
# 147       NaN  35.8  22.3  49.3    35.8   13.3
# 148       NaN  18.1  36.9  25.6    18.1   14.9

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Republic  295 non-null    float64
#  1   NDTV      300 non-null    float64
#  2   TV5       305 non-null    float64
#  3   TV9       297 non-null    float64
#  4   AajTak    300 non-null    float64
#  5   sales     305 non-null    float64
# dtypes: float64(6)
# memory usage: 14.4 KB

# %%
df['Republic'].fillna(df['Republic'].mean(), inplace=True)

# %%
df
# Out:
#      Republic  NDTV   TV5   TV9  AajTak  sales
# 0         8.7  48.9   4.0  75.0    49.0    7.2
# 1        57.5  32.8  65.9  23.5    57.5   11.8
# 2       120.2  19.6   7.2  11.6    18.5   13.2
# 3         8.6   2.1  46.0   1.0     2.6    4.8
# 4       199.8   2.6  52.9  21.2     2.9   10.6
# ..        ...   ...   ...   ...     ...    ...
# 300     286.0  13.9  35.2   3.7    13.9   15.9
# 301      18.7  12.1  23.7  23.4    18.7    6.7
# 302      39.5  41.1  17.6   5.8    39.5   10.8
# 303      75.5  10.8   8.3   6.0    75.5    9.9
# 304      17.2   4.1  30.0  31.6    17.2    5.9
#
# [305 rows x 6 columns]

# %%
df['NDTV'].fillna(df['NDTV'].mean(), inplace=True)

# %%
df['TV9'].fillna(df['TV9'].mean(), inplace=True)

# %%
df['AajTak'].fillna(df['AajTak'].mean(), inplace=True)

# %%
df
# Out:
#      Republic  NDTV   TV5   TV9  AajTak  sales
# 0         8.7  48.9   4.0  75.0    49.0    7.2
# 1        57.5  32.8  65.9  23.5    57.5   11.8
# 2       120.2  19.6   7.2  11.6    18.5   13.2
# 3         8.6   2.1  46.0   1.0     2.6    4.8
# 4       199.8   2.6  52.9  21.2     2.9   10.6
# ..        ...   ...   ...   ...     ...    ...
# 300     286.0  13.9  35.2   3.7    13.9   15.9
# 301      18.7  12.1  23.7  23.4    18.7    6.7
# 302      39.5  41.1  17.6   5.8    39.5   10.8
# 303      75.5  10.8   8.3   6.0    75.5    9.9
# 304      17.2   4.1  30.0  31.6    17.2    5.9
#
# [305 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Republic    0
# NDTV        0
# TV5         0
# TV9         0
# AajTak      0
# sales       0
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig, axs = plt.subplots(1,3)

df.plot(kind= 'scatter', x= 'Republic', y= 'sales', ax=axs[0], figsize= (12,6))
df.plot(kind= 'scatter', x= 'NDTV', y= 'sales', ax=axs[1])
df.plot(kind= 'scatter', x= 'AajTak', y= 'sales', ax=axs[2])
fig.savefig('Model building test')

# %%
x = df[['Republic']]
y = df.sales

from sklearn.linear_model import LinearRegression

lm = LinearRegression()

lm.fit(x,y)
# Out:
# LinearRegression()

# %%
print(lm.intercept_)
print(lm.coef_)
# Out:
# 6.889665736162409
# [0.04672585]
